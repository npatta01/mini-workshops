# %% [markdown]
# # reference
# https://towardsdatascience.com/word-embedding-with-word2vec-and-fasttext-a209c1d3e12c

# %%
import numpy as np
import os
from random import shuffle
import re
import urllib.request
import zipfile
import lxml.etree
import gensim

# %%
#download the data
urllib.request.urlretrieve("https://wit3.fbk.eu/get.php?path=XML_releases/xml/ted_en-20160408.zip&filename=ted_en-20160408.zip", filename="ted_en-20160408.zip")
# extract subtitle
with zipfile.ZipFile('ted_en-20160408.zip', 'r') as z:
    doc = lxml.etree.parse(z.open('ted_en-20160408.xml', 'r'))
input_text = '\n'.join(doc.xpath('//content/text()'))

# %%
# remove parenthesis 
input_text_noparens = re.sub(r'\([^)]*\)', '', input_text)
# store as list of sentences
sentences_strings_ted = []
for line in input_text_noparens.split('\n'):
    m = re.match(r'^(?:(?P<precolon>[^:]{,20}):)?(?P<postcolon>.*)$', line)
    sentences_strings_ted.extend(sent for sent in m.groupdict()['postcolon'].split('.') if sent)
# store as list of lists of words
sentences_ted = []
for sent_str in sentences_strings_ted:
    tokens = re.sub(r"[^a-z0-9]+", " ", sent_str.lower()).split()
    sentences_ted.append(tokens)

# %%
model_ted_word2vec = gensim.models.Word2Vec(sentences=sentences_ted, size=100, window=5, min_count=5, workers=4, sg=0)

# %%
model_ted_word2vec.wv.vocab
# Out:
# {'here': <gensim.models.keyedvectors.Vocab at 0x1114a1668>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x1a3a5d3ef0>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x1a3a5d3f28>,
#  'reasons': <gensim.models.keyedvectors.Vocab at 0x1a3a5d3f60>,
#  'companies': <gensim.models.keyedvectors.Vocab at 0x1a3a5d3f98>,
#  'fail': <gensim.models.keyedvectors.Vocab at 0x1a3a5f1048>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x1a3a5f1080>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x1a3a5f10b8>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x1a3a5f10f0>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x1a3a5f1128>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x1a3a5f1160>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x1a3a5f1198>,
#  'same': <gensim.models.keyedvectors.Vocab at 0x1a3a5f11d0>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x1a3a5f1208>,
#  'what': <gensim.models.keyedvectors.Vocab at 0x1a3a5f1240>,
# ...

# %%
model_ted_word2vec.wv.most_similar(positive=["biology"], negative=[])
# Out:
# [('physics', 0.7809040546417236),
#  ('architecture', 0.7564115524291992),
#  ('evolution', 0.7446974515914917),
#  ('complexity', 0.7437461614608765),
#  ('chemistry', 0.7364258766174316),
#  ('mathematics', 0.7363711595535278),
#  ('science', 0.7246834635734558),
#  ('psychology', 0.7150701880455017),
#  ('neuroscience', 0.7111603021621704),
#  ('mechanics', 0.7029778957366943)]

# %%
model_ted_word2vec.wv.most_similar(positive=["hope"], negative=[])
# Out:
# [('promise', 0.6673669219017029),
#  ('believe', 0.6012292504310608),
#  ('wish', 0.5442450642585754),
#  ('future', 0.516074538230896),
#  ('think', 0.5002747178077698),
#  ('suppose', 0.4968940019607544),
#  ('mean', 0.49221450090408325),
#  ('love', 0.4918864369392395),
#  ('hopefully', 0.4908878803253174),
#  ('dream', 0.4878457188606262)]

# %%
model_ted_word2vec.wv.most_similar(“man”)
# Out:
#   File "<ipython-input-7-00436cd4dc4f>", line 1
#     model_ted.wv.most_similar(“man”)
#                                   ^
# SyntaxError: invalid character in identifier

# %%
model_ted_fasttext = gensim.models.FastText(sentences_ted, size=100, window=5, min_count=5, workers=4,sg=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-169a2f65b5b2> in <module>()
# ----> 1 model_ted_fast = FastText(sentences_ted, size=100, window=5, min_count=5, workers=4,sg=1)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/gensim/models/fasttext.py in __init__(self, sentences, sg, hs, size, alpha, window, min_count, max_vocab_size, word_ngrams, sample, seed, workers, min_alpha, negative, cbow_mean, hashfxn, iter, null_word, min_n, max_n, sorted_vocab, bucket, trim_rule, batch_words, callbacks)
#     276             sentences=sentences, workers=workers, vector_size=size, epochs=iter, callbacks=callbacks,
#     277             batch_words=batch_words, trim_rule=trim_rule, sg=sg, alpha=alpha, window=window, seed=seed,
# --> 278             hs=hs, negative=negative, cbow_mean=cbow_mean, min_alpha=min_alpha, fast_version=FAST_VERSION)
#     279
# ...

# %%
model_ted_fasttext.wv.most_similar("Gastroenteritis")

# %%
model_ted_fasttext.wv.most_similar("Gastroenteritis")
